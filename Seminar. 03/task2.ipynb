# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def runge(x):
    return 1 / (1 + 25 * x**2)

x_points = list(np.linspace(-1, 1, 5))
y_points = [runge(current) for current in x_points]


def lagrance_poly(x_points, y_points, x):
    result = 0

    for i in range(len(x_points)):
        term = y_points[i]
        for j in range(len(x_points)):
            if i != j:
                term *= (x - x_points[j]) / (x_points[i] - x_points[j])
        result += term
    return result

# %%
x_range = np.linspace(-1, 1 , 100)
runge_values = [runge(current) for current in x_range]
appr_values = [lagrance_poly(x_points, y_points, current) for current in x_range]

# %%
plt.plot(x_range, runge_values)
plt.plot(x_range, appr_values)
plt.show()
